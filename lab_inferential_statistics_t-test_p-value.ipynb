# %% [markdown]
# # Lab Inferential statistics - T-test & P-value

# %% [markdown]
# ## Library loading

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1. We will have another simple example on two sample t test (pooled- when the variances are equal). But this time this is a one sided t-test
#
# In a packing plant, a machine packs cartons with jars. It is supposed that a new machine will pack faster on the average than the machine currently used. To test that hypothesis, the times it takes each machine to pack ten cartons are recorded. The results, in seconds, are shown in the tables in the file files_for_lab/machine.txt. Assume that there is sufficient evidence to conduct the t test, does the data provide sufficient evidence to show if one machine is better than the other

# %%
# Import libraries
from sklearn.feature_selection import VarianceThreshold
import pandas as pd 
from sklearn.feature_selection import RFE
from sklearn import linear_model
import math

# %%
df = pd.read_excel('/content/drive/MyDrive/unit8/day2/lab-t-tests-p-values/files_for_lab/machine.xlsx')
df.head(10)
# Out:
#     new   old
# 0  42.1  42.7
# 1  41.0  43.6
# 2  41.3  43.8
# 3  41.8  43.3
# 4  42.4  42.5
# 5  42.8  43.5
# 6  43.2  43.1
# 7  42.3  41.7
# 8  41.8  44.0
# 9  42.7  44.1

# %%
new_mean = df['new'].mean()
new_mean
# Out:
# 42.14

# %%
old_mean = df['old'].mean()
old_mean
# Out:
# 43.230000000000004

# %%
df['new'].std()
# Out:
# 0.6834552736727638

# %%
df['old'].std()
# Out:
# 0.7498888806572157

# %%
sample_mean1 = 42.14
sample_std1 = 0.68
n1 = 10
sample_mean2 = 43.23
sample_std2 = 0.75
n2 = 10
pooled_sample_std = math.sqrt(((n1-1)*sample_std1**2 + (n2-1)*sample_std2**2)/(n1+n2-2))
statistic = (sample_mean1-sample_mean2)/(pooled_sample_std*math.sqrt((1/n1)+(1/n2)))
print("T Statistic is: ", statistic)
# Out:
# T Statistic is:  -3.4047540987884606

# %%
from scipy.stats import t

print("P value is: ", 1- t.cdf(statistic,n1+n2-2))
print("Critical Value of z is: ", t.ppf(0.025, n1+n2-2)) #alpha is 0.05
# Out:
# P value is:  0.9984209598073223
# Critical Value of z is:  -2.10092204024096

# %% [markdown]
# We will accept the Null hypothesis, because the critical value is higher than the statistics value and the P-value is more than the significance value.

# %% [markdown]
# ## 2. An additional problem (not mandatory): In this case we can't assume that the population variances are equal. Hence in this case we cannot pool the variances. Independent random samples of 17 sophomores and 13 juniors attending a large university yield the following data on grade point averages. Data is provided in the file files_for_lab/student_gpa.txt. At the 5% significance level, do the data provide sufficient evidence to conclude that the mean GPAs of sophomores and juniors at the university differ?
#
# Test statistics can be calculated as: link to the image - Test statistics calculation for Unpooled Variance Case
#
# Degrees of freedom is (n1-1)+(n2-1).

# %%
df = pd.read_excel('/content/drive/MyDrive/unit8/day2/lab-t-tests-p-values/files_for_lab/student_gpa.xlsx')
df.head(18)
# Out:
#     sophomores  juniors
# 0         3.04     2.56
# 1         1.71     2.77
# 2         3.30     2.70
# 3         2.88     3.00
# 4         2.11     2.98
# 5         2.60     3.47
# 6         2.92     3.26
# 7         3.60     3.20
# 8         2.28     3.19
# 9         2.82     2.65
# 10        3.03     3.00
# 11        3.13     3.39
# 12        2.86     2.58
# 13        3.49      NaN
# 14        3.11      NaN
# 15        2.13      NaN
# 16        3.27      NaN

# %%
s_mean = df['sophomores'].mean()
s_mean
# Out:
# 2.8400000000000003

# %%
j_mean = df['juniors'].mean()
j_mean
# Out:
# 2.980769230769231

# %%
df['sophomores'].std()
# Out:
# 0.5198317035349037

# %%
df['juniors'].std()
# Out:
# 0.3092588327615327

# %%
j_mean = df['juniors'].mean()
j_std = df['juniors'].std()
n1 = 13
s_mean = df['sophomores'].mean()
s_std = df['sophomores'].std()
n2 = 17
pooled_sample_std = math.sqrt(((n1-1)*j_std**2 + (n2-1)*s_std**2)/(n1+n2-2))
statistic = (j_mean-s_mean)/(pooled_sample_std*math.sqrt((1/n1)+(1/n2)))
print("T Statistic is: ", statistic)
# Out:
# T Statistic is:  0.8643254553234221

# %%
print("P value is: ", 1- t.cdf(statistic,n1+n2-2))
print("Critical Value of z is: ", t.ppf(0.025, n1+n2-2)) #alpha is 0.05
# Out:
# P value is:  0.19737679833348065
# Critical Value of z is:  -2.048407141795244

# %% [markdown]
# Critical value < statistic value ==> reject Null Hypothesis?
#
# P-value > significant value ==> accept Null hypothesis?
#
# It looks like there is not sufficient evidence to conclude that the mean GPA's of sophomores and juniors differ.
